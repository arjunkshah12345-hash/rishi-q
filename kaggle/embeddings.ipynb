# %% [markdown]
# # RISHI-Q Secondary Embeddings
#
# **Not the primary experiment.**

# %%
from pathlib import Path
OUTPUT = Path("/kaggle/working") if Path("/kaggle/working").exists() else Path("../results/exploratory/kaggle")
OUTPUT.mkdir(parents=True, exist_ok=True)
(OUTPUT / "embeddings_PLACEHOLDER.txt").write_text(
    "Run with pinned sentence-transformers on GPU; record model revision in manifest.\n",
    encoding="utf-8",
)
print("secondary only")
